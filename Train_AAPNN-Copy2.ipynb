# %% [markdown]
# # Aging Aware with Model Variation
# Previously, we optimize the following functional:
# $$ \min_\theta \, \int_{t=0}^{1} \; L(\theta(t)) \, {\rm d}t. $$
# The optimum is for a specific aging model $\omega$, i.e., we minimized the
# $$ \min_\theta \, \int_{t=0}^{1} \; L(\theta(t,\omega)) \, {\rm d}t. $$
# However, we dont know how will the resistance decay, i.e., we should also minimize the loss function w.r.t. aging models with different parameters. That means we need to optimized
# $$ \min_\theta \, \int_{\omega}\int_{t=0}^{1} \; L(\theta(t,\omega)) \, {\rm d}t\, p(\omega){\rm d}\omega. $$
# The Mento Carlo Approximation is then
# $$
# \min_{\theta_{\rm init}} \frac{1}{\Omega}\frac{1}{K}\sum_{\omega\in\mathfrak{M}}\sum_{k\in \mathfrak{K} } L \left(\theta[k, \omega]\right),
# $$
# where $\mathfrak{M}$ is the set of $\Omega$ elements following the distribution $p(\omega)$. $p(\omega)$ is the distributions of parameters of the aging model. We have already obtained these distributions as we modeled the aging decay.
#
# That means we should optimize this problem by
# $$
# \begin{align}
# \theta_{\rm init}&:=\theta_{\rm init} - \alpha\cdot\nabla_{\theta_{\rm init}}\left(\frac{1}{\Omega}\frac{1}{K}\sum_{\omega\in\mathfrak{M}}\sum_{k\in \mathfrak{K} } L \left(\theta[k, \omega]\right)\right)\\
# &=\theta_{\rm init} - \frac{\alpha}{\Omega K}\cdot\nabla_{\theta_{\rm init}}\left(\sum_{\omega\in\mathfrak{M}}\sum_{k\in \mathfrak{K} } L \left(\theta[k, \omega]\right)\right)\\
# &=\theta_{\rm init} - \frac{\alpha}{\Omega K}\left(\sum_{\omega\in\mathfrak{M}}\sum_{k\in \mathfrak{K} }\nabla_{\theta_{\rm init}} L \left(\theta[k, \omega]\right)\right)
# \end{align}
# $$

# %% [markdown]
# # Import library

# %%
import importlib
from torch.autograd import Variable
import torch
import pickle
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import pNN_aging_aware_vectorization as pnnv
import training_vectorization as tv
import random
import config
import evaluation_vectorization as ev
sys.path.append(os.path.join(os.getcwd(), 'Aging_Model'))

# %% [markdown]
# # Random Seed

# %%
seed = 2

# %% [markdown]
# # Get Aging Model

# %%
with open(os.path.join(os.getcwd(), 'Aging_Model', 'exp_aging_model.p'), 'rb') as f:
    age_generator = pickle.load(f)

# %% [markdown]
# # Device

# %%
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cuda:0')
device = 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# # Prepare data

# %% [markdown]
# ## Dataset

# %%
if config.current_dataset is not None:
    ds = config.datasets[config.current_dataset]
else:
    ds = config.datasets[0]

ds
# Out:
# 'VertebralColumn_c2'

# %% [markdown]
# ## Load data

# %%
datapath = os.path.join(os.getcwd(), 'Datasets',
                        'dataset_processed', f'Dataset_{ds}.p')
with open(datapath, 'rb') as f:
    dataset = pickle.load(f)
X = dataset['X'].float()
y = dataset['y']

E, N_features, N_class = X.shape[0], X.shape[1], torch.max(
    torch.unique(y)).item()+1
X.shape, y.shape, E, N_features, N_class
# Out:
# (torch.Size([310, 6]), torch.Size([310]), 310, 6, 2)

# %% [markdown]
# ## Pseudo-electrical Signal

# %%
X = X - torch.min(X, axis=0)[0]
X = X / (torch.max(X, axis=0)[0])
torch.min(X), torch.max(X)
# Out:
# (tensor(0.), tensor(1.))

# %%
X[:10, :9]
# Out:
# tensor([[0.3557, 0.5198, 0.2292, 0.2509, 0.3075, 0.0252],
#         [0.1245, 0.2967, 0.0986, 0.1446, 0.4767, 0.0364],
#         [0.4117, 0.5139, 0.3230, 0.3076, 0.3862, 0.0175],
#         [0.4162, 0.5573, 0.2713, 0.2894, 0.3419, 0.0518],
#         [0.2272, 0.2894, 0.1282, 0.2470, 0.4096, 0.0442],
#         [0.1360, 0.3657, 0.0995, 0.1199, 0.6479, 0.0309],
#         [0.2631, 0.4003, 0.2074, 0.2239, 0.5430, 0.0397],
#         [0.1854, 0.3092, 0.1346, 0.1966, 0.5075, 0.0009],
#         [0.1701, 0.3587, 0.2568, 0.1563, 0.5906, 0.0567],
#         [0.1017, 0.2065, 0.2501, 0.1694, 0.1523, 0.0273]])

# %%
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from torch.utils.data import random_split

# generate tensordataset
dataset = TensorDataset(X.to(device), y.to(device))

# split
train_rate = 0.6
test_rate = 0.2
valid_rate = 0.2
E_train = min(8192, int(E*train_rate))
E_test = min(2048, int(E*test_rate))
E_valid = min(2048, int(E*valid_rate))


random.seed(config.data_split_seed);
np.random.seed(config.data_split_seed);
torch.manual_seed(config.data_split_seed);

train_data, rest_data = random_split(dataset, [E_train, E-E_train])
test_data, rest_data = random_split(rest_data, [E_test, E-E_train-E_test])
valid_data, rest_data = random_split(rest_data, [E_valid, E-E_train-E_test-E_valid])

len(train_data), len(test_data), len(valid_data)
# Out:
# (186, 62, 62)

# %%
# batch
train_loader = DataLoader(train_data, batch_size=len(train_data))
test_loader = DataLoader(test_data, batch_size=len(test_data))
valid_loader = DataLoader(valid_data, batch_size=len(valid_data))

# %% [markdown]
# # Aging Aware PNN

# %%
random.seed(seed);
np.random.seed(seed);
torch.manual_seed(seed);

# %%
AAPNN = torch.nn.Sequential(pnnv.PNNLayer(N_features, config.N_Hidden, age_generator, xpu=device),
                           pnnv.PNNLayer(config.N_Hidden, N_class, age_generator, xpu=device))

AAPNN.apply(lambda z: pnnv.MakeModel(z, config.M_train))
AAPNN.apply(lambda z: pnnv.SetTime(z, np.random.rand(config.K_train).tolist()))

AAPNN.to(device)
# Out:
# Sequential(
#   (0): PNNLayer()
#   (1): PNNLayer()
# )

# %% [markdown]
# ## Reload AAPNN if crash

# %%
# if os.path.exists(f'./temp/{ds}_AAPNN.p'): 
#     with open(f'./temp/{ds}_AAPNN.p', 'rb') as f:
#         AAPNN = pickle.load(f)

# %% [markdown]
# ## Training

# %%
optimizer_AAPNN = torch.optim.Adam(AAPNN.parameters(), lr=config.AAPNN_lr_1)
train_loader = DataLoader(train_data, batch_size=min(len(train_data),1024))
train_loss_AAPNN, test_loss_AAPNN, parameter_AAPNN = tv.train_aged_pnn(AAPNN, train_loader, test_loader,
                                        config.m, config.T, config.M_train, config.K_train, config.M_test, config.K_test,
                                        optimizer_AAPNN, pnnv.LossFunction,
                                        Epoch=150, cache=ds)
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# | Epoch:     0 | Accuracy: 0.62298 | Loss: 0.664072394 |
# | Epoch:     7 | Accuracy: 0.63379 | Loss: 0.675172627 |
# | Epoch:    14 | Accuracy: 0.66661 | Loss: 0.591001511 |
# | Epoch:    21 | Accuracy: 0.67855 | Loss: 0.544761896 |
# | Epoch:    28 | Accuracy: 0.67395 | Loss: 0.565813541 |
# | Epoch:    35 | Accuracy: 0.68242 | Loss: 0.546514273 |
# | Epoch:    42 | Accuracy: 0.68694 | Loss: 0.550490558 |
# | Epoch:    49 | Accuracy: 0.69145 | Loss: 0.528173387 |
# | Epoch:    56 | Accuracy: 0.68661 | Loss: 0.536570430 |
# | Epoch:    63 | Accuracy: 0.69613 | Loss: 0.527237833 |
# | Epoch:    70 | Accuracy: 0.69694 | Loss: 0.527664721 |
# | Epoch:    77 | Accuracy: 0.68831 | Loss: 0.524584174 |
# | Epoch:    84 | Accuracy: 0.70468 | Loss: 0.492597789 |
# | Epoch:    91 | Accuracy: 0.71452 | Loss: 0.513424754 |
# | Epoch:    98 | Accuracy: 0.72218 | Loss: 0.496150404 |
# | Epoch:   105 | Accuracy: 0.72806 | Loss: 0.495953709 |
# | Epoch:   112 | Accuracy: 0.71798 | Loss: 0.507724941 |
# | Epoch:   119 | Accuracy: 0.73250 | Loss: 0.465365708 |
# | Epoch:   126 | Accuracy: 0.73145 | Loss: 0.487852186 |
# | Epoch:   133 | Accuracy: 0.74508 | Loss: 0.432284713 |
# | Epoch:   140 | Accuracy: 0.75226 | Loss: 0.434510916 |
# | Epoch:   147 | Accuracy: 0.75315 | Loss: 0.428375870 |
# Finished.

# %%
plt.plot(train_loss_AAPNN, '-', label='train')
plt.plot(test_loss_AAPNN, '--', label='test')
plt.legend()
best = np.argmin(test_loss_AAPNN)
AAPNN.load_state_dict(parameter_AAPNN)
best, test_loss_AAPNN[best]
# Out:
# (149, 0.42722710967063904)

# %%
optimizer_AAPNN = torch.optim.Adam(AAPNN.parameters(), lr=config.AAPNN_lr_2)
train_loader = DataLoader(train_data, batch_size=len(train_data))
train_loss_AAPNN, test_loss_AAPNN, parameter_AAPNN = tv.train_aged_pnn(AAPNN, train_loader, test_loader,
                                        config.m, config.T, config.M_train, config.K_train, config.M_test, config.K_test,
                                        optimizer_AAPNN, pnnv.LossFunction,
                                        Epoch=250, cache=ds)
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# | Epoch:     0 | Accuracy: 0.74266 | Loss: 0.465521425 |
# | Epoch:    12 | Accuracy: 0.75331 | Loss: 0.440335184 |
# | Epoch:    24 | Accuracy: 0.75290 | Loss: 0.461438328 |
# | Epoch:    36 | Accuracy: 0.76952 | Loss: 0.419234663 |
# | Epoch:    48 | Accuracy: 0.76887 | Loss: 0.410064369 |
# | Epoch:    60 | Accuracy: 0.77484 | Loss: 0.412621230 |
# | Epoch:    72 | Accuracy: 0.77266 | Loss: 0.421266466 |
# | Epoch:    84 | Accuracy: 0.77500 | Loss: 0.393706143 |
# | Epoch:    96 | Accuracy: 0.77403 | Loss: 0.411510319 |
# | Epoch:   108 | Accuracy: 0.78677 | Loss: 0.388845176 |
# | Epoch:   120 | Accuracy: 0.78040 | Loss: 0.394500941 |
# | Epoch:   132 | Accuracy: 0.76718 | Loss: 0.441232294 |
# | Epoch:   144 | Accuracy: 0.78573 | Loss: 0.394724518 |
# | Epoch:   156 | Accuracy: 0.79532 | Loss: 0.374401569 |
# | Epoch:   168 | Accuracy: 0.79040 | Loss: 0.395154923 |
# | Epoch:   180 | Accuracy: 0.79468 | Loss: 0.375478834 |
# | Epoch:   192 | Accuracy: 0.80048 | Loss: 0.364310175 |
# | Epoch:   204 | Accuracy: 0.78500 | Loss: 0.382678688 |
# | Epoch:   216 | Accuracy: 0.78855 | Loss: 0.399200410 |
# | Epoch:   228 | Accuracy: 0.78669 | Loss: 0.386252522 |
# | Epoch:   240 | Accuracy: 0.79403 | Loss: 0.380310297 |
# Finished.

# %%
plt.plot(train_loss_AAPNN, '-', label='train')
plt.plot(test_loss_AAPNN, '--', label='test')
plt.legend()
best = np.argmin(test_loss_AAPNN)
AAPNN.load_state_dict(parameter_AAPNN)
best, test_loss_AAPNN[best]
# Out:
# (232, 0.3595714569091797)

# %%
optimizer_AAPNN = torch.optim.Adam(AAPNN.parameters(), lr=config.AAPNN_lr_3)
train_loader = DataLoader(train_data, batch_size=len(train_data))
train_loss_AAPNN, test_loss_AAPNN, parameter_AAPNN = tv.train_aged_pnn(AAPNN, train_loader, test_loader,
                                        config.m, config.T, config.M_train, config.K_train, config.M_test, config.K_test,
                                        optimizer_AAPNN, pnnv.LossFunction,
                                        Epoch=250, cache=ds)
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# | Epoch:     0 | Accuracy: 0.79282 | Loss: 0.379399478 |
# | Epoch:    12 | Accuracy: 0.78919 | Loss: 0.392224401 |
# | Epoch:    24 | Accuracy: 0.80250 | Loss: 0.359500051 |
# | Epoch:    36 | Accuracy: 0.79339 | Loss: 0.377966821 |
# | Epoch:    48 | Accuracy: 0.80177 | Loss: 0.357361943 |
# | Epoch:    60 | Accuracy: 0.78435 | Loss: 0.399572670 |
# | Epoch:    72 | Accuracy: 0.80831 | Loss: 0.363692522 |
# | Epoch:    84 | Accuracy: 0.79903 | Loss: 0.370546371 |
# | Epoch:    96 | Accuracy: 0.79081 | Loss: 0.387825459 |
# | Epoch:   108 | Accuracy: 0.80500 | Loss: 0.367669731 |
# | Epoch:   120 | Accuracy: 0.78992 | Loss: 0.392978668 |
# | Epoch:   132 | Accuracy: 0.78145 | Loss: 0.391341269 |
# | Epoch:   144 | Accuracy: 0.79371 | Loss: 0.380645216 |
# | Epoch:   156 | Accuracy: 0.79508 | Loss: 0.380230904 |
# | Epoch:   168 | Accuracy: 0.80056 | Loss: 0.360718012 |
# | Epoch:   180 | Accuracy: 0.80129 | Loss: 0.364336461 |
# | Epoch:   192 | Accuracy: 0.79524 | Loss: 0.370640993 |
# | Epoch:   204 | Accuracy: 0.79597 | Loss: 0.385389060 |
# | Epoch:   216 | Accuracy: 0.79637 | Loss: 0.367320508 |
# | Epoch:   228 | Accuracy: 0.80056 | Loss: 0.371632874 |
# | Epoch:   240 | Accuracy: 0.80637 | Loss: 0.367900461 |
# Finished.

# %%
plt.plot(train_loss_AAPNN, '-', label='train')
plt.plot(test_loss_AAPNN, '--', label='test')
plt.legend()
best = np.argmin(test_loss_AAPNN)
AAPNN.load_state_dict(parameter_AAPNN)
best, test_loss_AAPNN[best]
# Out:
# (73, 0.34265124797821045)

# %% [markdown]
# ## Save Model

# %%
with open(f'./result/{ds}_AAPNN_{seed}.p', 'wb') as f:
    pickle.dump(AAPNN, f)

# %% [markdown]
# # Evaluation

# %%
mean_acc_AAPNN, std_acc_AAPNN, mean_maa_AAPNN, std_maa_AAPNN = ev.Evaluation(AAPNN, valid_loader, config.M_valid, int(config.M_valid/10), config.K_valid, device)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
np.savetxt(f'./result/figures/{ds}_AAPNN_ACC_{seed}_{int(np.mean(mean_acc_AAPNN)*1000)}.txt', np.vstack((mean_acc_AAPNN, std_acc_AAPNN)))
np.savetxt(f'./result/figures/{ds}_AAPNN_MAA_{seed}_{int(np.mean(mean_maa_AAPNN)*1000)}.txt', np.vstack((mean_maa_AAPNN, std_maa_AAPNN)))
