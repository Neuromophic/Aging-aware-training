# %%
import pickle
import pNN_aging_aware as pnn
import numpy as np
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# # get aging model

# %%
import os
import aging_model_generator as amg

with open('linear_aging_model.p', 'rb') as f:
    aging_model_generator = pickle.load(f)

# %%
my_agi = aging_model_generator.get_models(10)

# %%
vals = np.linspace(0,1,100)
for i in range(10):
    plt.plot(vals, mymodel[i](vals))

# %%
mynetwork = torch.nn.Sequential(pnn.PNNLayer(1,3, aging_model_generator=aging_model_generator),
                                ...

# %%
mymodel[i].params
# Out:
# array([-2.75736966, -0.21111954,  0.76978511])
